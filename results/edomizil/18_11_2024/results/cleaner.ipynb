# %%
import pandas as pd 
import os
import csv
from datetime import datetime, timedelta

# %%
date_scrap = "18/11/2024"

# %%
all_files = os.listdir()    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
dfs = []

for csv_file in csv_files:
    dfs.append(pd.read_csv(csv_file))

len(dfs)
# Out:
# 4

# %%
df = pd.concat(dfs)

# %%
df['date_scrap'] = date_scrap

# %%
df.drop_duplicates(inplace=True, subset=['date_debut', 'date_fin', 'price', 'identifiant',
       'typologie', 'nom'])
len(df)
# Out:
# 10733

# %%
df['date_debut'] = pd.to_datetime(df['date_debut'], format='%d/%m/%Y')
df = df.sort_values(by=['date_debut'])
df['date_debut'] = df['date_debut'].dt.strftime('%d/%m/%Y')

# %%
df.head()
# Out:
#       date_scrap  date_debut    date_fin    price identifiant  \
# 687   18/11/2024  23/11/2024  30/11/2024  1673.47     HS95PC1
# 672   18/11/2024  23/11/2024  30/11/2024  1618.73     HVE0D43
# 1860  18/11/2024  23/11/2024  30/11/2024  1738.40     HR34JVE
# 653   18/11/2024  23/11/2024  30/11/2024  1475.82     HRK8M93
# 1870  18/11/2024  23/11/2024  30/11/2024   896.96     HG6215D
#
#                                               typologie                  nom
# 687           125 m² Chalet ∙ 4 chambres ∙ 10 personnes   Hérémence - Valais
# 672       101 m² Appartement ∙ 2 chambres ∙ 5 personnes  Saas Grund - Valais
# 1860       90 m² Appartement ∙ 2 chambres ∙ 5 personnes    Saas Fee - Valais
# 653   160 m² Maison de vacances ∙ 4 chambres ∙ 9 per...      Riddes - Valais
# 1870             Appartement ∙ 3 chambres ∙ 5 personnes     Grächen - Valais

# %%
df.to_csv(f"edomizil_cleaned_{date_scrap.replace('/', '_')}.csv", index=False)
