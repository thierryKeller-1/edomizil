# %%
import pandas as pd 
import os
import csv
from datetime import datetime, timedelta

# %%
date_scrap = "11/11/2024"

# %%
all_files = os.listdir()    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
dfs = []

for csv_file in csv_files:
    dfs.append(pd.read_csv(csv_file))

len(dfs)
# Out:
# 4

# %%
df = pd.concat(dfs)

# %%
df['date_scrap'] = date_scrap

# %%
df.drop_duplicates(inplace=True, subset=['date_debut', 'date_fin', 'price', 'identifiant',
       'typologie', 'nom'])
len(df)
# Out:
# 13170

# %%
df['date_debut'] = pd.to_datetime(df['date_debut'], format='%d/%m/%Y')
df = df.sort_values(by=['date_debut'])
df['date_debut'] = df['date_debut'].dt.strftime('%d/%m/%Y')

# %%
df.head()
# Out:
#       date_scrap  date_debut    date_fin    price identifiant  \
# 0     28/10/2024  02/11/2024  09/11/2024   464.88     HZVS437
# 1177  28/10/2024  02/11/2024  09/11/2024  1068.25     HL4S5AZ
# 2680  28/10/2024  02/11/2024  09/11/2024   610.49     H1ZDBVW
# 2661  28/10/2024  02/11/2024  09/11/2024  1198.79     HGT8VB5
# 2646  28/10/2024  02/11/2024  09/11/2024   764.68     HYX9RDE
#
#                                               typologie                  nom
# 0     50 m² Maison de vacances ∙ 1 chambre ∙ 4 perso...        Leuk - Valais
# 1177  190 m² Maison de vacances ∙ 4 chambres ∙ 12 pe...         Vex - Valais
# 2680       42 m² Appartement ∙ 2 chambres ∙ 6 personnes      Nendaz - Valais
# 2661       90 m² Appartement ∙ 3 chambres ∙ 6 personnes    Saas Fee - Valais
# 2646        34 m² Appartement ∙ 1 chambre ∙ 2 personnes  Saas Grund - Valais

# %%
df.to_csv(f"edomizil_cleaned_{date_scrap.replace('/', '_')}.csv", index=False)
