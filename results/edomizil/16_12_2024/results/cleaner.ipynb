# %%
import pandas as pd 
import os
import csv
from datetime import datetime, timedelta

# %%
date_scrap = "16/12/2024"

# %%
all_files = os.listdir()    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
dfs = []

for csv_file in csv_files:
    dfs.append(pd.read_csv(csv_file))

len(dfs)
# Out:
# 4

# %%
df = pd.concat(dfs)

# %%
df['date_scrap'] = date_scrap

# %%
df.drop_duplicates(inplace=True, subset=['date_debut', 'date_fin', 'price', 'identifiant',
       'typologie', 'nom'])
len(df)
# Out:
# 17265

# %%
df['date_debut'] = pd.to_datetime(df['date_debut'], format='%d/%m/%Y')
df = df.sort_values(by=['date_debut'])
df['date_debut'] = df['date_debut'].dt.strftime('%d/%m/%Y')

# %%
df.head()
# Out:
#       date_scrap  date_debut    date_fin     price identifiant  \
# 1783  16/12/2024  21/12/2024  28/12/2024   834.00      HV0YZX9
# 4159  16/12/2024  21/12/2024  28/12/2024  1029.92      HDF6ZB3
# 2873  16/12/2024  21/12/2024  28/12/2024  2655.03      HCPU1Z2
# 906   16/12/2024  21/12/2024  28/12/2024  1503.28      HW37AMG
# 4150  16/12/2024  21/12/2024  28/12/2024  1128.17      HSDEN1Y
#
#                                               typologie  \
# 1783  55 m² Appartement ∙ 4 personnes ∙ 1 chambre∙1 ...
# 4159       32 m² Appartement ∙ 3 personnes ∙ 1 chambre0
# 2873      105 m² Appartement ∙ 6 personnes ∙ 3 chambres
# 906   68 m² Appartement ∙ 4 personnes ∙ 2 chambres∙1...
# 4150  Appartement ∙ 4 personnes ∙ 1 chambre∙1 salle ...
#
#                                                     nom
# 1783  Appartement de vacances avec terrasse | Vue mo...
# 4159     Agréable appartement avec barbecue et terrasse
# 2873                 Berg-Idyll Appartement avec 6 lits
# 906      Crans-Montana magnifique appartement plein sud
# 4150        Appartement avec 1 chambre pour 4 personnes

# %%
df.to_csv(f"edomizil_cleaned_{date_scrap.replace('/', '_')}.csv", index=False)
