# %%
import pandas as pd 
import os
import csv
from datetime import datetime, timedelta

# %%
all_files = os.listdir()    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
dfs = []

for csv_file in csv_files:
    dfs.append(pd.read_csv(csv_file))

len(dfs)
# Out:
# 4

# %%
df = pd.concat(dfs)

# %%
df.drop_duplicates(inplace=True, subset=['date_debut', 'date_fin', 'price', 'identifiant',
       'typologie', 'nom'])
len(df)
# Out:
# 15747

# %%
df['date_debut'] = pd.to_datetime(df['date_debut'], format='%d/%m/%Y')
df = df.sort_values(by=['date_debut'])
df['date_debut'] = df['date_debut'].dt.strftime('%d/%m/%Y')

# %%
df['date_scrap'] = "07/10/2024"

# %%
df.head()
# Out:
#       date_scrap  date_debut    date_fin    price identifiant  \
# 4530  07/10/2024  12/10/2024  19/10/2024  1980.30     HMTH2F8
# 2571  07/10/2024  12/10/2024  19/10/2024  1342.87     HR0J9YG
# 3700  07/10/2024  12/10/2024  19/10/2024   976.06     HTB573H
# 1603  07/10/2024  12/10/2024  19/10/2024   758.53     HRKFSLD
# 3164  07/10/2024  12/10/2024  19/10/2024  1027.42     HSZGPC4
#
#                                               typologie  \
# 4530     Maison de vacances ∙ 4 chambres ∙ 11 personnes
# 2571  140 m² Maison de vacances ∙ 4 chambres ∙ 8 per...
# 3700       65 m² Appartement ∙ 2 chambres ∙ 4 personnes
# 1603        30 m² Appartement ∙ 1 chambre ∙ 2 personnes
# 3164        44 m² Appartement ∙ 1 chambre ∙ 4 personnes
#
#                          nom
# 4530       Grimentz - Valais
# 2571  Troistorrents - Valais
# 3700  Saas-Almagell - Valais
# 1603       Saas Fee - Valais
# 3164       Saas Fee - Valais

# %%
df.to_csv('edomizil_cleaned_07_10_2024.csv', index=False)
