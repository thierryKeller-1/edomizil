# %%
import pandas as pd 
import os
import csv
from datetime import datetime, timedelta

# %%
all_files = os.listdir()    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
dfs = []

for csv_file in csv_files:
    dfs.append(pd.read_csv(csv_file))

len(dfs)
# Out:
# 4

# %%
df = pd.concat(dfs)

# %%
df.drop_duplicates(inplace=True, subset=['date_debut', 'date_fin', 'price', 'identifiant',
       'typologie', 'nom'])
len(df)
# Out:
# 16444

# %%
df['date_debut'] = pd.to_datetime(df['date_debut'], format='%d/%m/%Y')
df = df.sort_values(by=['date_debut'])
df['date_debut'] = df['date_debut'].dt.strftime('%d/%m/%Y')

# %%
df['date_scrap'] = "30/09/2024"

# %%
df.head()
# Out:
#       date_scrap  date_debut    date_fin    price identifiant  \
# 2834  30/09/2024  05/10/2024  12/10/2024  1375.52     H26C5ZK
# 1070  30/09/2024  05/10/2024  12/10/2024   773.00     HZ6D9MV
# 886   30/09/2024  05/10/2024  12/10/2024   879.00     HHDY4M9
# 518   30/09/2024  05/10/2024  12/10/2024  1191.54     HSUXEK3
# 897   30/09/2024  05/10/2024  12/10/2024   756.05     HB0XYF2
#
#                                          typologie                     nom
# 2834        Appartement ∙ 3 chambres ∙ 6 personnes         Ferden - Valais
# 1070   50 m² Appartement ∙ 1 chambre ∙ 4 personnes         Nendaz - Valais
# 886    76 m² Appartement ∙ 1 chambre ∙ 2 personnes        Zermatt - Valais
# 518   70 m² Appartement ∙ 2 chambres ∙ 5 personnes  Saas-Almagell - Valais
# 897    24 m² Appartement ∙ 1 chambre ∙ 2 personnes       Saas Fee - Valais

# %%
df.to_csv('edomizil_cleaned_30_09_2024.csv', index=False)
