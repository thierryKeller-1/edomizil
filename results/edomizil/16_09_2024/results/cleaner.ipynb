# %%
import pandas as pd 
import os
import csv
from datetime import datetime, timedelta

# %%
all_files = os.listdir()    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
dfs = []

for csv_file in csv_files:
    dfs.append(pd.read_csv(csv_file))

len(dfs)
# Out:
# 4

# %%
df = pd.concat(dfs)

# %%
df.drop_duplicates(inplace=True, subset=['date_debut', 'date_fin', 'price', 'identifiant',
       'typologie', 'nom'])
len(df)
# Out:
# 13788

# %%
df['date_debut'] = pd.to_datetime(df['date_debut'], format='%d/%m/%Y')
df = df.sort_values(by=['date_debut'])
df['date_debut'] = df['date_debut'].dt.strftime('%d/%m/%Y')

# %%
df['date_scrap'] = "26/08/2024"

# %%
df.head()
# Out:
#       date_scrap  date_debut    date_fin    price identifiant  \
# 3384  19/05/2024  24/08/2024  31/08/2024   415.00     H9UX4L7
# 3494  19/05/2024  24/08/2024  31/08/2024   650.59     HD3NRX2
# 5008  19/05/2024  24/08/2024  31/08/2024   913.04     HAW3PSD
# 1447  19/05/2024  24/08/2024  31/08/2024   661.37     H21C3BJ
# 196   19/05/2024  24/08/2024  31/08/2024  1233.97     HBJA29S
#
#                                               typologie  \
# 3384                                    Rosablanche D52
# 3494                          Appartement ∙ 2 personnes
# 5008       54 m² Appartement ∙ 2 chambres ∙ 5 personnes
# 1447        45 m² Appartement ∙ 1 chambre ∙ 4 personnes
# 196   155 m² Maison de vacances ∙ 5 chambres ∙ 10 pe...
#
#                                  nom
# 3384  Rosablanche D52Nendaz - Valais
# 3494                Grächen - Valais
# 5008           Zinal - Ayer - Valais
# 1447       Loèche-les-Bains - Valais
# 196                  Riddes - Valais

# %%
df.to_csv('edomizil_cleaned_26_08_2024.csv', index=False)
