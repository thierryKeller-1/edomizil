# %%
import pandas as pd 
import os
import csv
from datetime import datetime, timedelta

# %%
date_scrap = "25/11/2024"

# %%
all_files = os.listdir()    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
dfs = []

for csv_file in csv_files:
    dfs.append(pd.read_csv(csv_file))

len(dfs)
# Out:
# 4

# %%
df = pd.concat(dfs)

# %%
df['date_scrap'] = date_scrap

# %%
df.drop_duplicates(inplace=True, subset=['date_debut', 'date_fin', 'price', 'identifiant',
       'typologie', 'nom'])
len(df)
# Out:
# 9758

# %%
df['date_debut'] = pd.to_datetime(df['date_debut'], format='%d/%m/%Y')
df = df.sort_values(by=['date_debut'])
df['date_debut'] = df['date_debut'].dt.strftime('%d/%m/%Y')

# %%
df.head()
# Out:
#       date_scrap  date_debut    date_fin    price identifiant  \
# 1186  25/11/2024  30/11/2024  07/12/2024   744.20     HH27LDY
# 1506  25/11/2024  30/11/2024  07/12/2024   447.00     HS7LKC5
# 1677  25/11/2024  30/11/2024  07/12/2024  1051.91     HMDXU1S
# 1062  25/11/2024  30/11/2024  07/12/2024  1187.64     HC098BV
# 1560  25/11/2024  30/11/2024  07/12/2024   590.31     HG3SBZ7
#
#                                           typologie  \
# 1186  Maison de vacances ∙ 5 chambres ∙ 9 personnes
# 1506    28 m² Appartement ∙ 1 chambre ∙ 2 personnes
# 1677         Appartement ∙ 5 chambres ∙ 8 personnes
# 1062   70 m² Appartement ∙ 2 chambres ∙ 6 personnes
# 1560    37 m² Appartement ∙ 1 chambre ∙ 4 personnes
#
#                               nom
# 1186             Grächen - Valais
# 1506  Ovronnaz - Leytron - Valais
# 1677             Grächen - Valais
# 1062    Loèche-les-Bains - Valais
# 1560                 Vex - Valais

# %%
df.to_csv(f"edomizil_cleaned_{date_scrap.replace('/', '_')}.csv", index=False)
