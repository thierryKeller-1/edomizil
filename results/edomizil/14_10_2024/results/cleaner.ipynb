# %%
import pandas as pd 
import os
import csv
from datetime import datetime, timedelta

# %%
date_scrap = "14/10/2024"

# %%
all_files = os.listdir()    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
dfs = []

for csv_file in csv_files:
    dfs.append(pd.read_csv(csv_file))

len(dfs)
# Out:
# 4

# %%
df = pd.concat(dfs)

# %%
df['date_scrap'] = date_scrap

# %%
df.drop_duplicates(inplace=True, subset=['date_debut', 'date_fin', 'price', 'identifiant',
       'typologie', 'nom'])
len(df)
# Out:
# 14742

# %%
df['date_debut'] = pd.to_datetime(df['date_debut'], format='%d/%m/%Y')
df = df.sort_values(by=['date_debut'])
df['date_debut'] = df['date_debut'].dt.strftime('%d/%m/%Y')

# %%
df.head()
# Out:
#       date_scrap  date_debut    date_fin    price identifiant  \
# 1537  14/10/2024  19/10/2024  26/10/2024  1216.00     H17WP6F
# 124   14/10/2024  19/10/2024  26/10/2024   537.67     HHT6YEJ
# 455   14/10/2024  19/10/2024  26/10/2024   959.37     HKUST76
# 2181  14/10/2024  19/10/2024  26/10/2024  1320.20     H0LDK1B
# 2250  14/10/2024  19/10/2024  26/10/2024  2617.47     HXB139C
#
#                                               typologie  \
# 1537  140 m² Maison de vacances ∙ 4 chambres ∙ 8 per...
# 124         60 m² Appartement ∙ 1 chambre ∙ 4 personnes
# 455         63 m² Appartement ∙ 1 chambre ∙ 4 personnes
# 2181       60 m² Appartement ∙ 2 chambres ∙ 4 personnes
# 2250      140 m² Appartement ∙ 3 chambres ∙ 6 personnes
#
#                               nom
# 1537  Ovronnaz - Leytron - Valais
# 124            Veysonnaz - Valais
# 455             Saas Fee - Valais
# 2181       Saas-Almagell - Valais
# 2250            Saas Fee - Valais

# %%
df.to_csv(f"edomizil_cleaned_{date_scrap.replace('/', '_')}.csv", index=False)
