# %%
import pandas as pd 
import os
import csv
from datetime import datetime, timedelta

# %%
date_scrap = "09/12/2024"

# %%
all_files = os.listdir()    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
dfs = []

for csv_file in csv_files:
    dfs.append(pd.read_csv(csv_file))

len(dfs)
# Out:
# 4

# %%
df = pd.concat(dfs)

# %%
df['date_scrap'] = date_scrap

# %%
df.drop_duplicates(inplace=True, subset=['date_debut', 'date_fin', 'price', 'identifiant',
       'typologie', 'nom'])
len(df)
# Out:
# 13665

# %%
df['date_debut'] = pd.to_datetime(df['date_debut'], format='%d/%m/%Y')
df = df.sort_values(by=['date_debut'])
df['date_debut'] = df['date_debut'].dt.strftime('%d/%m/%Y')

# %%
df.head()
# Out:
#       date_scrap  date_debut    date_fin    price identifiant  \
# 913   09/12/2024  14/12/2024  21/12/2024   994.51     HGC1MP7
# 1556  09/12/2024  14/12/2024  21/12/2024  1019.38     HFKJS2R
# 509   09/12/2024  14/12/2024  21/12/2024   644.40     H5G93XN
# 6926  09/12/2024  14/12/2024  21/12/2024  1404.44     HB7MK8E
# 709   09/12/2024  14/12/2024  21/12/2024  2527.81     HH6JELU
#
#                                           typologie  \
# 913    90 m² Appartement ∙ 2 chambres ∙ 4 personnes
# 1556         Appartement ∙ 2 chambres ∙ 5 personnes
# 509     56 m² Appartement ∙ 1 chambre ∙ 4 personnes
# 6926    52 m² Appartement ∙ 4 personnes ∙ 1 chambre
# 709   120 m² Appartement ∙ 3 chambres ∙ 6 personnes
#
#                                 nom
# 913       Loèche-les-Bains - Valais
# 1556               Grächen - Valais
# 509             Saas Grund - Valais
# 6926   ∙ 1 chambreSaas Fee - Valais
# 709       Loèche-les-Bains - Valais

# %%
df.to_csv(f"edomizil_cleaned_{date_scrap.replace('/', '_')}.csv", index=False)
